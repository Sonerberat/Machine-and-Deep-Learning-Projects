# %% [markdown]
# # Capstone Project
# ## Image classifier for the SVHN dataset
# ### Instructions
#
# In this notebook, you will create a neural network that classifies real-world images digits. You will use concepts from throughout this course in building, training, testing, validating and saving your Tensorflow classifier model.
#
# This project is peer-assessed. Within this notebook you will find instructions in each section for how to complete the project. Pay close attention to the instructions as the peer review will be carried out according to a grading rubric that checks key parts of the project instructions. Feel free to add extra cells into the notebook as required.
#
# ### How to submit
#
# When you have completed the Capstone project notebook, you will submit a pdf of the notebook for peer review. First ensure that the notebook has been fully executed from beginning to end, and all of the cell outputs are visible. This is important, as the grading rubric depends on the reviewer being able to view the outputs of your notebook. Save the notebook as a pdf (File -> Download as -> PDF via LaTeX). You should then submit this pdf for review.
#
# ### Let's get started!
#
# We'll start by running some imports, and loading the dataset. For this project you are free to make further imports throughout the notebook as you wish.

# %%
import tensorflow as tf
from scipy.io import loadmat

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ![SVHN overview image](data/svhn_examples.jpg)
# For the capstone project, you will use the [SVHN dataset](http://ufldl.stanford.edu/housenumbers/). This is an  image dataset of over 600,000 digit images in all, and is a harder dataset than MNIST as the numbers appear in the context of natural scene images. SVHN is obtained from house numbers in Google Street View images.
#
# * Y. Netzer, T. Wang, A. Coates, A. Bissacco, B. Wu and A. Y. Ng. "Reading Digits in Natural Images with Unsupervised Feature Learning". NIPS Workshop on Deep Learning and Unsupervised Feature Learning, 2011.
#
# Your goal is to develop an end-to-end workflow for building, training, validating, evaluating and saving a neural network that classifies a real-world image into one of ten classes.

# %%
# Run this cell to load the dataset

train = loadmat('/content/drive/MyDrive/5/data/train_32x32.mat')
test = loadmat('/content/drive/MyDrive/5/data/test_32x32.mat')

# %% [markdown]
# Both `train` and `test` are dictionaries with keys `X` and `y` for the input images and labels respectively.

# %% [markdown]
# ## 1. Inspect and preprocess the dataset
# * Extract the training and testing images and labels separately from the train and test dictionaries loaded for you.
# * Select a random sample of images and corresponding labels from the dataset (at least 10), and display them in a figure.
# * Convert the training and test images to grayscale by taking the average across all colour channels for each pixel. _Hint: retain the channel dimension, which will now have size 1._
# * Select a random sample of the grayscale images and corresponding labels from the dataset (at least 10), and display them in a figure.

# %%
training_x = train['X']
training_y = train['y']
testing_x = test['X']
testing_y = test['y']
for i in range(0, len(training_y)):
    if training_y[i]  == 10:
        training_y[i] = 0
for i in range(0, len(testing_y)):
    if testing_y[i]  == 10:
        testing_y[i] = 0

# %%
for j in range(0,10):
    i = random.randint(0,training_x.shape[3])
    plt.imshow(training_x[:,:,:,i])
    plt.title(str(training_y[i]))
    plt.show()

# %%
# print(training_x.shape)
for i in range(0,training_x.shape[3]):
    training_x[:,:,0,i] = np.mean(training_x[:,:,:,i], axis=2)
    training_x[:,:,1,i] = np.mean(training_x[:,:,:,i], axis=2)
    training_x[:,:,2,i] = np.mean(training_x[:,:,:,i], axis=2)

for i in range(0,testing_x.shape[3]):
    testing_x[:,:,0,i] = np.mean(testing_x[:,:,:,i], axis=2)
    testing_x[:,:,1,i] = np.mean(testing_x[:,:,:,i], axis=2)
    testing_x[:,:,2,i] = np.mean(testing_x[:,:,:,i], axis=2)
    
for j in range(0,10):
    i = random.randint(0,training_x.shape[3])
    plt.imshow(training_x[:,:,:,i])
    plt.title(str(training_y[i]))
    plt.show()

xx = np.concatenate((training_x,testing_x),axis = 3)
yy = np.concatenate((training_y,testing_y),axis = 0)

xx=np.swapaxes(xx,3,0)
xx=np.swapaxes(xx,3,1)
xx=np.swapaxes(xx,3,2)

testing_x=np.swapaxes(testing_x,3,0)
testing_x=np.swapaxes(testing_x,3,1)
testing_x=np.swapaxes(testing_x,3,2)

training_x=np.swapaxes(training_x,3,0)
training_x=np.swapaxes(training_x,3,1)
training_x=np.swapaxes(training_x,3,2)

MLPtesting_x=testing_x[:,:,:,0]
MLPtraining_x=training_x[:,:,:,0]
MLPxx = xx[:,:,:,0]

# %% [markdown]
# ## 2. MLP neural network classifier
# * Build an MLP classifier model using the Sequential API. Your model should use only Flatten and Dense layers, with the final layer having a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different MLP architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 4 or 5 layers._
# * Print out the model summary (using the summary() method)
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * As a guide, you should aim to achieve a final categorical cross entropy training loss of less than 1.0 (the validation loss might be higher).
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
# print(training_x.shape)

model = Sequential([
            Flatten(name='flatten',input_shape=(32,32)),
            Dense(256,activation = 'relu',name = 'dense_1'),
            Dense(128,activation = 'relu',name = 'dense_2'),
            Dense(90,activation = 'relu',name = 'dense_3'),
            Dense(10,activation = 'softmax',name = 'dense_5')
        ])

model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
    )

Ckpt = tf.keras.callbacks.ModelCheckpoint(
    'checkpoints_best_only/checkpoint',
    monitor="val_acc",
    verbose=1,
    save_best_only=True,
    save_weights_only=True
    )

ES = tf.keras.callbacks.EarlyStopping(    
    monitor="val_acc",
    patience=5,
    verbose=1,
    )

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 90)                11610
#
#  dense_5 (Dense)             (None, 10)                910
#
# =================================================================
# Total params: 307,816
# Trainable params: 307,816
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(MLPtraining_x, training_y, epochs=30, validation_data=(MLPxx, yy), callbacks=[Ckpt,ES])
# Out:
# Epoch 1/30
# 2288/2290 [============================>.] - ETA: 0s - loss: 3.6411 - acc: 0.2291
# Epoch 1: val_acc improved from -inf to 0.35897, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 38s 16ms/step - loss: 3.6399 - acc: 0.2292 - val_loss: 1.9309 - val_acc: 0.3590
# Epoch 2/30
# 2286/2290 [============================>.] - ETA: 0s - loss: 1.6088 - acc: 0.4653
# Epoch 2: val_acc improved from 0.35897 to 0.45529, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 22s 10ms/step - loss: 1.6088 - acc: 0.4653 - val_loss: 1.7637 - val_acc: 0.4553
# Epoch 3/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 1.4122 - acc: 0.5415
# Epoch 3: val_acc improved from 0.45529 to 0.48440, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 24s 10ms/step - loss: 1.4123 - acc: 0.5415 - val_loss: 1.6049 - val_acc: 0.4844
# Epoch 4/30
# 2284/2290 [============================>.] - ETA: 0s - loss: 1.3340 - acc: 0.5728
# Epoch 4: val_acc improved from 0.48440 to 0.59582, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 23s 10ms/step - loss: 1.3343 - acc: 0.5727 - val_loss: 1.3041 - val_acc: 0.5958
# Epoch 5/30
# 2288/2290 [============================>.] - ETA: 0s - loss: 1.2832 - acc: 0.5923
# Epoch 5: val_acc improved from 0.59582 to 0.62439, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 26s 11ms/step - loss: 1.2832 - acc: 0.5923 - val_loss: 1.2081 - val_acc: 0.6244
# Epoch 6/30
# 2285/2290 [============================>.] - ETA: 0s - loss: 1.2239 - acc: 0.6142
# Epoch 6: val_acc did not improve from 0.62439
# 2290/2290 [==============================] - 25s 11ms/step - loss: 1.2235 - acc: 0.6144 - val_loss: 1.2197 - val_acc: 0.6170
# Epoch 7/30
# 2284/2290 [============================>.] - ETA: 0s - loss: 1.1989 - acc: 0.6235
# Epoch 7: val_acc improved from 0.62439 to 0.63762, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 23s 10ms/step - loss: 1.1991 - acc: 0.6234 - val_loss: 1.1657 - val_acc: 0.6376
# Epoch 8/30
# 2288/2290 [============================>.] - ETA: 0s - loss: 1.1669 - acc: 0.6348
# Epoch 8: val_acc did not improve from 0.63762
# 2290/2290 [==============================] - 19s 8ms/step - loss: 1.1670 - acc: 0.6348 - val_loss: 1.2341 - val_acc: 0.6058
# Epoch 9/30
# 2290/2290 [==============================] - ETA: 0s - loss: 1.1340 - acc: 0.6450
# Epoch 9: val_acc improved from 0.63762 to 0.65077, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 21s 9ms/step - loss: 1.1340 - acc: 0.6450 - val_loss: 1.1381 - val_acc: 0.6508
# Epoch 10/30
# 2284/2290 [============================>.] - ETA: 0s - loss: 1.1139 - acc: 0.6540
# Epoch 10: val_acc did not improve from 0.65077
# 2290/2290 [==============================] - 24s 10ms/step - loss: 1.1142 - acc: 0.6539 - val_loss: 1.1535 - val_acc: 0.6352
# Epoch 11/30
# 2288/2290 [============================>.] - ETA: 0s - loss: 1.0958 - acc: 0.6601
# Epoch 11: val_acc did not improve from 0.65077
# 2290/2290 [==============================] - 25s 11ms/step - loss: 1.0959 - acc: 0.6601 - val_loss: 1.1748 - val_acc: 0.6360
# Epoch 12/30
# 2283/2290 [============================>.] - ETA: 0s - loss: 1.0823 - acc: 0.6629
# Epoch 12: val_acc did not improve from 0.65077
# 2290/2290 [==============================] - 20s 9ms/step - loss: 1.0825 - acc: 0.6629 - val_loss: 1.1961 - val_acc: 0.6189
# Epoch 13/30
# 2284/2290 [============================>.] - ETA: 0s - loss: 1.0733 - acc: 0.6674
# Epoch 13: val_acc improved from 0.65077 to 0.66222, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 24s 10ms/step - loss: 1.0732 - acc: 0.6674 - val_loss: 1.0884 - val_acc: 0.6622
# Epoch 14/30
# 2287/2290 [============================>.] - ETA: 0s - loss: 1.0626 - acc: 0.6713
# Epoch 14: val_acc improved from 0.66222 to 0.67667, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 22s 10ms/step - loss: 1.0625 - acc: 0.6713 - val_loss: 1.0512 - val_acc: 0.6767
# Epoch 15/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 1.0516 - acc: 0.6757
# Epoch 15: val_acc did not improve from 0.67667
# 2290/2290 [==============================] - 19s 8ms/step - loss: 1.0517 - acc: 0.6757 - val_loss: 1.0647 - val_acc: 0.6703
# Epoch 16/30
# 2286/2290 [============================>.] - ETA: 0s - loss: 1.0485 - acc: 0.6758
# Epoch 16: val_acc did not improve from 0.67667
# 2290/2290 [==============================] - 24s 10ms/step - loss: 1.0486 - acc: 0.6757 - val_loss: 1.1065 - val_acc: 0.6592
# Epoch 17/30
# 2283/2290 [============================>.] - ETA: 0s - loss: 1.0381 - acc: 0.6803
# Epoch 17: val_acc did not improve from 0.67667
# 2290/2290 [==============================] - 18s 8ms/step - loss: 1.0381 - acc: 0.6803 - val_loss: 1.1167 - val_acc: 0.6554
# Epoch 18/30
# 2282/2290 [============================>.] - ETA: 0s - loss: 1.0281 - acc: 0.6807
# Epoch 18: val_acc improved from 0.67667 to 0.68552, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 24s 10ms/step - loss: 1.0282 - acc: 0.6805 - val_loss: 1.0420 - val_acc: 0.6855
# Epoch 19/30
# 2288/2290 [============================>.] - ETA: 0s - loss: 1.0283 - acc: 0.6819
# Epoch 19: val_acc improved from 0.68552 to 0.68937, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 23s 10ms/step - loss: 1.0282 - acc: 0.6820 - val_loss: 1.0273 - val_acc: 0.6894
# Epoch 20/30
# 2284/2290 [============================>.] - ETA: 0s - loss: 1.0205 - acc: 0.6855
# Epoch 20: val_acc improved from 0.68937 to 0.69363, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 22s 10ms/step - loss: 1.0209 - acc: 0.6853 - val_loss: 1.0066 - val_acc: 0.6936
# Epoch 21/30
# 2287/2290 [============================>.] - ETA: 0s - loss: 1.0132 - acc: 0.6882
# Epoch 21: val_acc did not improve from 0.69363
# 2290/2290 [==============================] - 18s 8ms/step - loss: 1.0130 - acc: 0.6883 - val_loss: 1.0325 - val_acc: 0.6871
# Epoch 22/30
# 2283/2290 [============================>.] - ETA: 0s - loss: 1.0152 - acc: 0.6878
# Epoch 22: val_acc did not improve from 0.69363
# 2290/2290 [==============================] - 23s 10ms/step - loss: 1.0152 - acc: 0.6877 - val_loss: 1.0279 - val_acc: 0.6824
# Epoch 23/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 1.0055 - acc: 0.6902
# Epoch 23: val_acc did not improve from 0.69363
# 2290/2290 [==============================] - 23s 10ms/step - loss: 1.0055 - acc: 0.6902 - val_loss: 1.0333 - val_acc: 0.6848
# Epoch 24/30
# 2284/2290 [============================>.] - ETA: 0s - loss: 1.0075 - acc: 0.6907
# Epoch 24: val_acc did not improve from 0.69363
# 2290/2290 [==============================] - 23s 10ms/step - loss: 1.0074 - acc: 0.6907 - val_loss: 1.0066 - val_acc: 0.6927
# Epoch 25/30
# 2288/2290 [============================>.] - ETA: 0s - loss: 1.0029 - acc: 0.6927
# Epoch 25: val_acc improved from 0.69363 to 0.70206, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 22s 10ms/step - loss: 1.0030 - acc: 0.6927 - val_loss: 0.9832 - val_acc: 0.7021
# Epoch 26/30
# 2286/2290 [============================>.] - ETA: 0s - loss: 0.9888 - acc: 0.6955
# Epoch 26: val_acc did not improve from 0.70206
# 2290/2290 [==============================] - 18s 8ms/step - loss: 0.9886 - acc: 0.6955 - val_loss: 0.9952 - val_acc: 0.6937
# Epoch 27/30
# 2284/2290 [============================>.] - ETA: 0s - loss: 0.9858 - acc: 0.6965
# Epoch 27: val_acc did not improve from 0.70206
# 2290/2290 [==============================] - 18s 8ms/step - loss: 0.9861 - acc: 0.6965 - val_loss: 1.0419 - val_acc: 0.6816
# Epoch 28/30
# 2287/2290 [============================>.] - ETA: 0s - loss: 0.9803 - acc: 0.6980
# Epoch 28: val_acc improved from 0.70206 to 0.70532, saving model to checkpoints_best_only/checkpoint
# 2290/2290 [==============================] - 18s 8ms/step - loss: 0.9801 - acc: 0.6981 - val_loss: 0.9712 - val_acc: 0.7053
# Epoch 29/30
# 2281/2290 [============================>.] - ETA: 0s - loss: 0.9797 - acc: 0.6992
# Epoch 29: val_acc did not improve from 0.70532
# 2290/2290 [==============================] - 22s 10ms/step - loss: 0.9792 - acc: 0.6994 - val_loss: 1.0325 - val_acc: 0.6835
# Epoch 30/30
# 2287/2290 [============================>.] - ETA: 0s - loss: 0.9759 - acc: 0.7025
# Epoch 30: val_acc did not improve from 0.70532
# 2290/2290 [==============================] - 22s 10ms/step - loss: 0.9760 - acc: 0.7025 - val_loss: 1.0388 - val_acc: 0.6906

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('ACCURACY')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('LOSS')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

# %%
test_loss, test_acc = model.evaluate(x=MLPtesting_x, y=testing_y, verbose=0)
print('test_loss',test_loss)
print('test_acc',test_acc)
# Out:
# test_loss 1.1524959802627563
# test_acc 0.6646050810813904

# %% [markdown]
# ## 3. CNN neural network classifier
# * Build a CNN classifier model using the Sequential API. Your model should use the Conv2D, MaxPool2D, BatchNormalization, Flatten, Dense and Dropout layers. The final layer should again have a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different CNN architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 2 or 3 convolutional layers and 2 fully connected layers.)_
# * The CNN model should use fewer trainable parameters than your MLP model.
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * You should aim to beat the MLP model performance with fewer parameters!
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
from tensorflow.keras.layers import BatchNormalization,Dropout
modelCNN = Sequential([
    Conv2D(16,3,activation = 'relu', padding = 'same',name ='conv_1',input_shape=(32,32,3)),
    Conv2D(8,(3,3),activation = 'relu', padding = 'same',name ='conv_2'),
    MaxPooling2D((8,8),name = 'pool_1'),
    Flatten(name='flatten'),
    BatchNormalization(name = 'norm'),
    Dense(64,activation = 'relu',name = 'dense_1'),
    Dropout(0.3),
    Dense(10,activation = 'softmax',name = 'dense_2')
])
modelCNN.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)
modelCNN.summary()
CkptCNN = tf.keras.callbacks.ModelCheckpoint(
    'checkpoints_best_onlyCNN/checkpointCNN',
    monitor="val_acc",
    verbose=1,
    save_best_only=True,
    save_weights_only=True
    )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 32, 32, 16)        448
#
#  conv_2 (Conv2D)             (None, 32, 32, 8)         1160
#
#  pool_1 (MaxPooling2D)       (None, 4, 4, 8)           0
#
#  flatten (Flatten)           (None, 128)               0
#
#  norm (BatchNormalization)   (None, 128)               512
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 11,026
# Trainable params: 10,770
# Non-trainable params: 256
# _________________________________________________________________

# %%
historyCNN = modelCNN.fit(training_x, training_y, epochs=30, validation_data=(xx, yy), callbacks=[CkptCNN,ES])
# Out:
# Epoch 1/30
# 2290/2290 [==============================] - ETA: 0s - loss: 1.3935 - acc: 0.5268
# Epoch 1: val_acc improved from -inf to 0.75643, saving model to checkpoints_best_onlyCNN/checkpointCNN
# 2290/2290 [==============================] - 134s 58ms/step - loss: 1.3935 - acc: 0.5268 - val_loss: 0.8156 - val_acc: 0.7564
# Epoch 2/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.9096 - acc: 0.7092
# Epoch 2: val_acc improved from 0.75643 to 0.78360, saving model to checkpoints_best_onlyCNN/checkpointCNN
# 2290/2290 [==============================] - 130s 57ms/step - loss: 0.9096 - acc: 0.7092 - val_loss: 0.7010 - val_acc: 0.7836
# Epoch 3/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.8203 - acc: 0.7400
# Epoch 3: val_acc improved from 0.78360 to 0.78485, saving model to checkpoints_best_onlyCNN/checkpointCNN
# 2290/2290 [==============================] - 128s 56ms/step - loss: 0.8203 - acc: 0.7400 - val_loss: 0.7258 - val_acc: 0.7849
# Epoch 4/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.7814 - acc: 0.7543
# Epoch 4: val_acc improved from 0.78485 to 0.81731, saving model to checkpoints_best_onlyCNN/checkpointCNN
# 2290/2290 [==============================] - 128s 56ms/step - loss: 0.7814 - acc: 0.7543 - val_loss: 0.6218 - val_acc: 0.8173
# Epoch 5/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.7525 - acc: 0.7630
# Epoch 5: val_acc improved from 0.81731 to 0.82686, saving model to checkpoints_best_onlyCNN/checkpointCNN
# 2290/2290 [==============================] - 129s 56ms/step - loss: 0.7525 - acc: 0.7630 - val_loss: 0.5761 - val_acc: 0.8269
# Epoch 6/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.7290 - acc: 0.7721
# Epoch 6: val_acc improved from 0.82686 to 0.83408, saving model to checkpoints_best_onlyCNN/checkpointCNN
# 2290/2290 [==============================] - 128s 56ms/step - loss: 0.7290 - acc: 0.7721 - val_loss: 0.5461 - val_acc: 0.8341
# Epoch 7/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.7138 - acc: 0.7760
# Epoch 7: val_acc did not improve from 0.83408
# 2290/2290 [==============================] - 130s 57ms/step - loss: 0.7138 - acc: 0.7760 - val_loss: 0.5752 - val_acc: 0.8321
# Epoch 8/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.7059 - acc: 0.7787
# Epoch 8: val_acc did not improve from 0.83408
# 2290/2290 [==============================] - 129s 57ms/step - loss: 0.7060 - acc: 0.7787 - val_loss: 0.5714 - val_acc: 0.8231
# Epoch 9/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.6910 - acc: 0.7836
# Epoch 9: val_acc improved from 0.83408 to 0.84467, saving model to checkpoints_best_onlyCNN/checkpointCNN
# 2290/2290 [==============================] - 130s 57ms/step - loss: 0.6910 - acc: 0.7836 - val_loss: 0.5163 - val_acc: 0.8447
# Epoch 10/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.6837 - acc: 0.7877
# Epoch 10: val_acc did not improve from 0.84467
# 2290/2290 [==============================] - 130s 57ms/step - loss: 0.6837 - acc: 0.7877 - val_loss: 0.5432 - val_acc: 0.8363
# Epoch 11/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.6773 - acc: 0.7877
# Epoch 11: val_acc did not improve from 0.84467
# 2290/2290 [==============================] - 132s 58ms/step - loss: 0.6773 - acc: 0.7877 - val_loss: 0.5358 - val_acc: 0.8389
# Epoch 12/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.6745 - acc: 0.7903
# Epoch 12: val_acc improved from 0.84467 to 0.85204, saving model to checkpoints_best_onlyCNN/checkpointCNN
# 2290/2290 [==============================] - 132s 58ms/step - loss: 0.6745 - acc: 0.7903 - val_loss: 0.4951 - val_acc: 0.8520
# Epoch 13/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.6649 - acc: 0.7928
# Epoch 13: val_acc did not improve from 0.85204
# 2290/2290 [==============================] - 132s 57ms/step - loss: 0.6649 - acc: 0.7928 - val_loss: 0.5954 - val_acc: 0.8201
# Epoch 14/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.6617 - acc: 0.7941
# Epoch 14: val_acc did not improve from 0.85204
# 2290/2290 [==============================] - 132s 58ms/step - loss: 0.6617 - acc: 0.7941 - val_loss: 0.5129 - val_acc: 0.8458
# Epoch 15/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.6547 - acc: 0.7958
# Epoch 15: val_acc did not improve from 0.85204
# 2290/2290 [==============================] - 135s 59ms/step - loss: 0.6547 - acc: 0.7958 - val_loss: 0.5119 - val_acc: 0.8475
# Epoch 16/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.6528 - acc: 0.7973
# Epoch 16: val_acc improved from 0.85204 to 0.85455, saving model to checkpoints_best_onlyCNN/checkpointCNN
# 2290/2290 [==============================] - 134s 58ms/step - loss: 0.6528 - acc: 0.7973 - val_loss: 0.4899 - val_acc: 0.8545
# Epoch 17/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.6459 - acc: 0.7978
# Epoch 17: val_acc did not improve from 0.85455
# 2290/2290 [==============================] - 133s 58ms/step - loss: 0.6459 - acc: 0.7978 - val_loss: 0.5141 - val_acc: 0.8443
# Epoch 18/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.6464 - acc: 0.7979
# Epoch 18: val_acc did not improve from 0.85455
# 2290/2290 [==============================] - 134s 58ms/step - loss: 0.6464 - acc: 0.7979 - val_loss: 0.4850 - val_acc: 0.8540
# Epoch 19/30
# 2290/2290 [==============================] - ETA: 0s - loss: 0.6437 - acc: 0.7990
# Epoch 19: val_acc did not improve from 0.85455
# 2290/2290 [==============================] - 132s 58ms/step - loss: 0.6437 - acc: 0.7990 - val_loss: 0.4905 - val_acc: 0.8518
# Epoch 20/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.6443 - acc: 0.7984
# Epoch 20: val_acc did not improve from 0.85455
# 2290/2290 [==============================] - 131s 57ms/step - loss: 0.6442 - acc: 0.7984 - val_loss: 0.5333 - val_acc: 0.8362
# Epoch 21/30
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.6367 - acc: 0.8018
# Epoch 21: val_acc did not improve from 0.85455
# 2290/2290 [==============================] - 133s 58ms/step - loss: 0.6367 - acc: 0.8018 - val_loss: 0.5029 - val_acc: 0.8478
# Epoch 21: early stopping

# %%
plt.plot(historyCNN.history['acc'])
plt.plot(historyCNN.history['val_acc'])
plt.title('ACCURACY')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

plt.plot(historyCNN.history['loss'])
plt.plot(historyCNN.history['val_loss'])
plt.title('LOSS')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

# %%
test_loss, test_acc = modelCNN.evaluate(x=testing_x, y=testing_y, verbose=0)
print('test_loss',test_loss)
print('test_acc',test_acc)
# Out:
# test_loss 0.5574595332145691
# test_acc 0.8364320993423462

# %% [markdown]
# ## 4. Get model predictions
# * Load the best weights for the MLP and CNN models that you saved during the training run.
# * Randomly select 5 images and corresponding labels from the test set and display the images with their labels.
# * Alongside the image and label, show each model’s predictive distribution as a bar chart, and the final model prediction given by the label with maximum probability.

# %%
ckMLP = tf.train.latest_checkpoint('checkpoints_best_only')
model.load_weights(ckMLP)

# %%
ckCNN = tf.train.latest_checkpoint('checkpoints_best_onlyCNN')
modelCNN.load_weights(ckCNN)

# %%
ans = modelCNN.predict(testing_x)
ans = model.predict(MLPtesting_x)

# %%
for j in range(0,5):
    f, ax  = plt.subplots(1,2)

    i = random.randint(0,MLPtesting_x.shape[0])
    ax[0].imshow(MLPtesting_x[i])
    ax[0].set_title(str(testing_y[i]))
    
    ans = model.predict(np.array([MLPtesting_x[i]]))
    ax[1].bar([10,1,2,3,4,5,6,7,8,9],ans[0])
    ax[1].set_title(str(np.argmax(ans)))
    plt.show()

# %%
for j in range(0,5):
    f, ax  = plt.subplots(1,2)

    i = random.randint(0,testing_x.shape[0])
    ax[0].imshow(testing_x[i])
    ax[0].set_title(str(testing_y[i]))
    
    ans = modelCNN.predict(np.array([testing_x[i]]))
    ax[1].bar([10,1,2,3,4,5,6,7,8,9],ans[0])
    ax[1].set_title(str(np.argmax(ans)))
    plt.show()
